# %%
# !pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5973 sha256=5e786fa8689d6ad74d15e95543404ae8c58ac26ff166eec32c1ba625ed004437
#   Stored in directory: /root/.cache/pip/wheels/1b/02/6c/a45230be8603bd95c0a51cd2b289aefdd860c1a100eab73661
# Successfully built apyori
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing

# %%
import apyori
from apyori import apriori

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cddbb7ff-640b-4c21-936d-ef652765bba3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cddbb7ff-640b-4c21-936d-ef652765bba3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#reading dataset
import pandas as pd
import numpy as np
import io

data = pd.read_csv(io.BytesIO(uploaded['Market_basket_analysis.csv']))
print(data)
# Out:
#                 Item 1             Item 2         Item 3            Item 4  \
# 0               shrimp            almonds        avocado    vegetables mix
# 1              burgers          meatballs           eggs               NaN
# 2               turkey            avocado            NaN               NaN
# 3        mineral water               milk     energy bar  whole wheat rice
# 4    whole wheat pasta       french fries            NaN               NaN
# ..                 ...                ...            ...               ...
# 923      herb & pepper  frozen vegetables  mineral water           muffins
# 924             turkey           tomatoes      spaghetti              milk
# 925      herb & pepper           red wine      spaghetti              eggs
# 926          green tea                NaN            NaN               NaN
# 927      grated cheese        ground beef      spaghetti           chicken
#
# ...

# %%
# number of rows, columns
data.shape
# Out:
# (928, 15)

# %%
# number of null values in each column
data.isnull().sum()
# Out:
# Item 1       0
# Item 2     145
# Item 3     319
# Item 4     454
# Item 5     562
# Item 6     663
# Item 7     733
# Item 8     780
# Item 9     830
# Item 10    868
# Item 11    893
# Item 12    911
# Item 13    920
# Item 14    925
# Item 15    927
# dtype: int64

# %%
# type of column
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 928 entries, 0 to 927
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Item 1   928 non-null    object
#  1   Item 2   783 non-null    object
#  2   Item 3   609 non-null    object
#  3   Item 4   474 non-null    object
#  4   Item 5   366 non-null    object
#  5   Item 6   265 non-null    object
#  6   Item 7   195 non-null    object
#  7   Item 8   148 non-null    object
#  8   Item 9   98 non-null     object
#  9   Item 10  60 non-null     object
#  10  Item 11  35 non-null     object
#  11  Item 12  17 non-null     object
#  12  Item 13  8 non-null      object
#  13  Item 14  3 non-null      object
#  14  Item 15  1 non-null      object
# dtypes: object(15)
# memory usage: 108.9+ KB

# %%
data.head()
# Out:
#               Item 1        Item 2      Item 3            Item 4  \
# 0             shrimp       almonds     avocado    vegetables mix
# 1            burgers     meatballs        eggs               NaN
# 2             turkey       avocado         NaN               NaN
# 3      mineral water          milk  energy bar  whole wheat rice
# 4  whole wheat pasta  french fries         NaN               NaN
#
#          Item 5            Item 6 Item 7          Item 8        Item 9  \
# 0  green grapes  whole weat flour   yams  cottage cheese  energy drink
# 1           NaN               NaN    NaN             NaN           NaN
# 2           NaN               NaN    NaN             NaN           NaN
# 3     green tea               NaN    NaN             NaN           NaN
# 4           NaN               NaN    NaN             NaN           NaN
#
#         Item 10         Item 11    Item 12 Item 13 Item 14        Item 15
# ...

# %%
#converting dataframe into list of lists
dataframe_list=[]

# values of range is according to the number of rows and columns
for i in range(1,750):
  dataframe_list.append([str(data.values[i,j]) for j in range(0,10)])

# %%
#applying apriori algorithm
association_rules = apriori(dataframe_list, min_support=0.0045, min_confidence=0.2,min_lift=3,min_length=2)
association_results = list(association_rules)

# %%
association_results[0]
# Out:
# RelationRecord(items=frozenset({'burgers', 'almonds'}), support=0.009345794392523364, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'burgers'}), confidence=0.3333333333333333, lift=3.962962962962963)])

# %%
Rule = []
Support = []
Confidence = []
Lift = []

for item in association_results:
    pair = item[0]
    items = [x for x in pair]
    Rule.append(items)
    Support.append(str(item[1]))
    Confidence.append(str(item[2][0][2]))
    Lift.append(str(item[2][0][3]))

# %%
#iterate through the list of associations and for each item
count=0
for item in association_results:

    #for each item filter out the item pair and create item list containing individual items in the itemset
    itemset = item[0]
    items = [x for x in itemset]

    #Print the relationship( First value in items to second value in items)
    print("Rule : ", items[0], " -> " + items[1])

    #Print support,confidence and lift value of each itemset
    print("Support : ", str(item[1]))
    print("Confidence : ",str(item[2][0][2]))
    print("Lift : ", str(item[2][0][3]))
    count=count+1
    print("=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>")
print(count)
# Out:
# Rule :  burgers  -> almonds
# Support :  0.009345794392523364
# Confidence :  0.3333333333333333
# Lift :  3.962962962962963
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
# Rule :  almonds  -> soup
# Support :  0.009345794392523364
# Confidence :  0.3333333333333333
# Lift :  3.8410256410256407
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
# Rule :  avocado  -> milk
# Support :  0.014686248331108143
# Confidence :  0.4230769230769231
# Lift :  3.106711915535445
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
# Rule :  barbecue sauce  -> soup
# Support :  0.0053404539385847796
# Confidence :  0.5
# Lift :  5.7615384615384615
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
# Rule :  black tea  -> spaghetti
# Support :  0.006675567423230975
# Confidence :  0.625
# Lift :  3.1845238095238098
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
# Rule :  body spray  -> soup
# Support :  0.006675567423230975
# Confidence :  0.5
# Lift :  5.7615384615384615
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
# ...
